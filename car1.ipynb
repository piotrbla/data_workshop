# %%
ls
# Out:
# sample_data/

# %%
cd /content/drive/My Drive/Colab Notebooks/data_workshop
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop

# %%
cd data/
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop/data

# %%
import pandas as pd

# %%
df = pd.read_hdf('car.h5')
df.shape
# Out:
# (106494, 155)

# %%
pip install --upgrade tables
# Out:
# Collecting tables
#   Downloading https://files.pythonhosted.org/packages/ed/c3/8fd9e3bb21872f9d69eb93b3014c86479864cca94e625fd03713ccacec80/tables-3.6.1-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 2.8MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /usr/local/lib/python3.6/dist-packages (from tables) (1.17.5)
# Requirement already satisfied, skipping upgrade: numexpr>=2.6.2 in /usr/local/lib/python3.6/dist-packages (from tables) (2.7.1)
# Installing collected packages: tables
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.6.1

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/My Drive/Colab Notebooks/data_workshop
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop

# %%
cd ..
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop

# %%
df = pd.read_hdf('data/car.h5')
df.shape
# Out:
# (106494, 155)

# %%
df.sample(2)
# Out:
#                                                breadcrumb  ...  car_id
# 132682                            [Osobowe, Nissan, Juke]  ...  132682
# 149375  [Osobowe, Ford, Mondeo, Ford Mondeo Mk2 (1996-...  ...  149375
#
# [2 rows x 155 columns]

# %%
df.head()
# Out:
#                                           breadcrumb  ... car_id
# 0    [Osobowe, Dacia, Logan, Dacia Logan II (2012-)]  ...      0
# 2  [Osobowe, Peugeot, 3008, Peugeot 3008 I (2009-...  ...      2
# 3  [Osobowe, Porsche, Cayenne, Porsche Cayenne II...  ...      3
# 4  [Osobowe, Peugeot, 308, Peugeot 308 T7 (2008-2...  ...      4
# 5  [Osobowe, Volkswagen, Golf, Volkswagen Golf VI...  ...      5
#
# [5 rows x 155 columns]
